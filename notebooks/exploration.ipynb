# %%
from src.data_ingestion import load_csv
from src.basic_exploration import basic_data_exploration

df = load_csv('../data/realtor-data.csv')

# %%
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
basic_data_exploration(df)
# Out:
# Dataset Overview
# ----------------
# Shape: (1401066, 10)
#
# Data Types:
# status             object
# bed               float64
# bath              float64
# acre_lot          float64
# city               object
# state              object
# zip_code          float64
# house_size        float64
# prev_sold_date     object
# price             float64
# dtype: object
#
# Missing Values:
# status                 0
# bed               216528
# bath              194213
# acre_lot          357467
# city                 191
# state                  0
# zip_code             479
# house_size        450112
# prev_sold_date    686293
# price                108
# dtype: int64
#
# Duplicate Rows: 1249026
#
# Statistical Summary (Numerical Data)
# ------------------------------------
#                 bed          bath      acre_lot      zip_code    house_size  \
# count  1.184538e+06  1.206853e+06  1.043599e+06  1.400587e+06  9.509540e+05
# ...

# %% [markdown]
# Test exploration on other CSVs

# %%
df = load_csv('../data/EbayPcLaptopsAndNetbooksUnclean.csv')
basic_data_exploration(df)
# Out:
# Dataset Overview
# ----------------
# Shape: (6620, 23)
#
# Data Types:
# Brand                             object
# Price                             object
# Rating                            object
# Ratings Count                    float64
# Condition                         object
# Seller Note                       object
# Processor                         object
# Screen Size                       object
# Manufacturer Color                object
# Color                             object
# Ram Size                          object
# SSD Capacity                      object
# GPU                               object
# Processor Speed                   object
# Type                              object
# Release Year                      object
# Maximum Resolution                object
# Model                             object
# OS                                object
# Features                          object
# Hard Drive Capacity               object
# ...

# %%
df = load_csv('../data/Electric_Vehicle_Population_Data.csv')
basic_data_exploration(df)
# Out:
# Dataset Overview
# ----------------
# Shape: (166800, 17)
#
# Data Types:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# ...

# %%
df = load_csv('../data/airline_review.csv')
basic_data_exploration(df)
# Out:
# Dataset Overview
# ----------------
# Shape: (3616, 20)
#
# Data Types:
# Unnamed: 0              int64
# rating                  int64
# header                 object
# author                 object
# date                   object
# place                  object
# content                object
# aircraft               object
# traveller_type         object
# seat_type              object
# route                  object
# date_flown             object
# seat_comfort            int64
# cabin_staff_service     int64
# food_beverages          int64
# ground_service          int64
# value_for_money         int64
# recommended            object
# entertainment           int64
# trip_verified          object
# dtype: object
#
# Missing Values:
# Unnamed: 0                0
# rating                    0
# header                    0
# author                    0
# date                      0
# place                     0
# content                   0
# aircraft               1714
# ...

# %% [markdown]
# Test on empty csv

# %%
df = load_csv('../data/empty.csv')
basic_data_exploration(df)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = load_csv('../data/empty.csv')
#       2 basic_data_exploration(df)
#
# File /mnt/file/Python/projects/pipeline/analysis-pipeline/src/data_ingestion.py:8, in load_csv(file_path)
#       6 """Load csv file into a pandas dataframe"""
#       7 try:
# ----> 8     return pd.read_csv(file_path)
#       9 except FileNotFoundError:
#      10     print("File not found")
#
# ...
